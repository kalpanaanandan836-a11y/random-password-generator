# %%
#random password generator
import random 
print("welcome to random password generator")
randomchars="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz1234567890!@#$%^&*"
numberofpassword=int(input("please enter the number of passwords to be generated:"))
passwordlen=int(input("please enter the length of the password needed"))
print("here are your random password")
for x in range (numberofpassword):
    password=""
    for chars in range (passwordlen):
        password=password+random.choice(randomchars)
    print (password)
# Out:
# welcome to random password generator
# please enter the number of passwords to be generated: 8
# please enter the length of the password needed 10
# here are your random password
# nozsE!K4Om
# !IbXte2Rwe
# CK^x%K3K@n
# KSwWxT*j5m
# kkn6TqgS29
# n*CnwO5zys
# 6m*4cbp7PY
# mr!wJGvP0$
